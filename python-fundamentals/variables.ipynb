# %%
var1 = "hello"

# %%
print(var1)
# Out:
# hello

# %%
item = 101
print(type(item))
# Out:
# <class 'int'>

# %%
# Never do that! Don't assign a value of a different type to the same variable!
item = "Code 101"
print(type(item))
# Out:
# <class 'str'>
