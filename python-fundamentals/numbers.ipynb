# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
import math

print(type(1.0))
print("When comparing floats directly, we may run into precision issues:")
print("0.1 * 3 == 0.3: ", 0.1 * 3 == 0.3)
print("To tackle this, we can use the mathisclose() function:")
print("math.isclose(0.1 * 3, 0.3): ", math.isclose(0.1 * 3, 0.3))
# Out:
# <class 'float'>
# When comparing floats directly, we may run into precision issues:
# 0.1 * 3 == 0.3:  False
# To tackle this, we can use the mathisclose() function:
# math.isclose(0.1 * 3, 0.3):  True

# %% [markdown]
# ## Arithmetic Operations
#
# - `+`, `-`, `*`, `/`
# - `/` true division -> float
# - `//` floor division -> integer or float
# - `%` modulo -> remainder
# - `**` -> power

# %%
print(8/2)
print(type(8/2))
print(5/3)
print(8//2)
print(type(8//2))
print(5//3)
print(5/3.0)
print(5%3) # 1 as the result, and 2 remaining
# Out:
# 4.0
# <class 'float'>
# 1.6666666666666667
# 4
# <class 'int'>
# 1
# 1.6666666666666667
# 2

# %%
refund = 14.54 + 20.43 + 16.16
print(refund)
total = 72.68 - refund
print(total)
# Out:
# 51.129999999999995
# 21.55000000000001
